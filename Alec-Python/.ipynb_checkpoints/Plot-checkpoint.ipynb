# %% [markdown]
# ## 長條圖
#
# ### 長條圖代表的是許多種類的數值，例如數量。常見的長條圖包括垂直與水平圖、堆疊圖及分組圖。

# %%
#!/usr/bin/env python3
import matplotlib.pyplot as plt
plt.style.use('ggplot')  # 使用 ggplot 樣式表來模仿 ggplot2 的風格，這是一種受歡迎的 R 繪圖套件。

# 建立長條圖的資料
customers = ['John', 'Mary', 'Andy', 'Ryan', 'Lucy']
customers_index = range(len(customers))  # 建立一串顧客索引值，因為 xticks 函式需要用索引位置與標籤來設定標籤。
print("customers_index = ", customers_index)
sale_amounts = [127, 90, 201, 111, 232]

fig = plt.figure()  # 建立一張圖。
ax1 = fig.add_subplot(1,1,1)  # 在圖內加入一張小圖，1,1,1 代表一列，一欄，以及第一個且唯一的小圖。
ax1.bar(customers_index, sale_amounts, align='center', color='darkorange')  # 建立長條圖，customers_index 指定長條圖左側
# 的 x 座標，sale_amounts 指定長條的高度，align='center'指定長條在它們的標籤上置中，color='darkblue'指定長條顏色。
ax1.xaxis.set_ticks_position('bottom') # 指定刻度標記位於下方，移除上方標記。
ax1.yaxis.set_ticks_position('left')   # 指定刻度標記位於左方，移除右方標記。
plt.xticks(customers_index, customers, rotation=30, fontsize='small') # 將長條的刻度標籤文字從顧客的索引號碼改為它們的姓名
# rotation=30 指定刻度標籤文字的角度。fontsize='small' 會減少刻度標籤文字的大小。

plt.xlabel('Customer Name')  # x 軸標籤。
plt.ylabel('Sale Amount')    # y 軸標籤。
plt.title('Sale Amount per Customer') # 圖表的標題。

plt.savefig('bar_plot.png', dpi=400, bbox_inches='tight') # 在目前資料夾將圖表存為 bar_plot.png，bbox_inches='tight' 在儲存
# 的圖表周圍加上空白區域。
plt.show()  # 在螢幕新視窗顯示圖表。

# %% [markdown]
# ## 色階分布圖
#
# ### 色階分布圖可表示數值的分布情形。常見的色階分布圖包括頻率分布、頻率密度分布、機率分布，以及機率密度分布。

# %%
#!/usr/bin/env python3
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

mu1, mu2, sigma = 100, 130, 15
# 使用亂數產生器來建立兩個常態分布變數。
x1 = mu1 + sigma*np.random.randn(10000)
x2 = mu2 + sigma*np.random.randn(10000)

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
n, bins, patches = ax1.hist(x1, bins=50, density=False, color='darkgreen') # density=False 表示這個色階分布圖應顯示頻率分布
                                                                           # 而不是機率分布。
n, bins, patches = ax1.hist(x2, bins=50, density=False, color='darkorange', alpha=0.5) # alpha=0.5 表示比較透明。
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')

plt.xlabel('Bins')
plt.ylabel('Number of Values in Bin')
fig.suptitle('Histograms', fontsize=14, fontweight='bold') # 為圖表加入一個置中標題，字體大小 14，粗體。
ax1.set_title('Two Frequency Distributions') # 為小圖加入置中標題，在圖表的標題下面。

plt.savefig('histogram.png', dpi=400, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 線型圖
#
# ### 線型圖可呈現沿著一條數字線的數值。它經常被用來顯示資料隨著時間推移的情形。

# %%
#!/usr/bin/env python3
from numpy.random import randn
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# 用 randn 建立要繪製的隨機資料
plot_data1 = randn(50).cumsum()
plot_data2 = randn(50).cumsum()
plot_data3 = randn(50).cumsum()
plot_data4 = randn(50).cumsum()

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.plot(plot_data1, marker=r'o', color=u'blue', linestyle='-', label='Blue Solid')
ax1.plot(plot_data2, marker=r'+', color=u'red', linestyle='--', label='Red Dashed')
ax1.plot(plot_data3, marker=r'*', color=u'green', linestyle='-.', label='Green Dash Dot')
ax1.plot(plot_data4, marker=r's', color=u'orange', linestyle=':', label='Orange Dotted')
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')

ax1.set_title('Line Plots: Markers, Colors, and Linestyles')
plt.xlabel('Draw')
plt.ylabel('Random Number')
plt.legend(loc='best')  # 建立圖表的圖例，loc='best' 會指示 matplotlib 將圖例放在圖表開放空間的最佳位置

plt.savefig('line_plot.png', dpi=400, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 散布圖
#
# ### 散布圖可展示兩個座標軸所代表的數值變數的值，例如，身高 vs. 體重，或供應 vs. 需求。散布圖可提供一些提示，讓你瞭解變數是否呈現正相關（即，都集中在一個特定的位置）或負相關（即，點會像擴散雲一樣散開）。你也可以繪製穿越點的迴歸線、最小平方誤差，來根據一個變數的值來預測另一個變數。

# %%
#!/usr/bin/env python3
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

x = np.arange(start=1., stop=15., step=1.)
# 使用稍微偏離線性與二次多項式方程式的亂數來建立資料
y_linear = x + 5. * np.random.randn(14)
y_quadratic = x**2 + 10. * np.random.randn(14)

# 使用 numpy 的 polyfit 與 polyld 函式來建立通過 (x, y_linear) 與 (x, y_quadratic) 的線性直線與二次多項式方程式曲線。
# 在真實世界的資料中，你可以使用 polyfit 函式來計算多項式的係數，來指定擬合程度。polyld 函式使用係數來建立實際的多項式方程式。
fn_linear = np.poly1d(np.polyfit(x, y_linear, deg=1))
fn_quadratic = np.poly1d(np.polyfit(x, y_quadratic, deg=2))

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 建立有兩條迴歸線的散布圖，'bo' 代表 (x, y_linear) 點是藍色圓圈，'go' 代表 (x, y_quadratic) 點是綠色圓圈。同樣的，'b-'
# 代表穿越 (x, y_linear) 點的線條是藍色實線，'g-' 代表穿越 (x, y_quadratic) 點的線條是綠色實線。可以用 linewidth 來指定線寬。
ax1.plot(x, y_linear, 'bo', x, y_quadratic, 'go', \
			x, fn_linear(x), 'b-', x, fn_quadratic(x), 'g-', linewidth=2.)
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')

ax1.set_title('Scatter Plots with Best Fit Lines')
plt.xlabel('x')
plt.ylabel('f(x)')

# 設定 x 軸與 y 軸的限制。線條使用 min 與 max 函式，根據實際的資料值來限制座標軸。你也可以使用特定的數字，例如 xlim(0, 20) 與
# ylim(0, 200)。如果你沒有指定座標軸限制，matplotlib 會為你設定限制。
plt.xlim((min(x)-1., max(x)+1.))
plt.ylim((min(y_quadratic)-10., max(y_quadratic)+10.))

plt.savefig('scatter_plot.png', dpi=400, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 盒鬚圖
#
# ### 盒鬚圖會根據資料的最小值、第一四分位數、中位數、第三四分位數，以及最大值來顯示資料。盒子的最下面與最上面是第一與第三四分位數，盒子中間那條線是中位數。從盒子兩端延伸的直線（稱為鬚）是最小與最大的非離群值，而鬚之外的點是離群值。

# %%
#!/usr/bin/env python3
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

N = 500
normal = np.random.normal(loc=0.0, scale=1.0, size=N)
lognormal = np.random.lognormal(mean=0.0, sigma=1.0, size=N)
#index_value = np.random.random_integers(low=0, high=N-1, size=N)  # This function is deprecated
index_value = np.random.randint(low=0, high=N-1, size=N)
normal_sample = normal[index_value]
lognormal_sample = lognormal[index_value]
box_plot_data = [normal,normal_sample,lognormal,lognormal_sample]

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 建立一個串列 box_labels，裡面存有每一個盒鬚圖的標籤。下一行的 boxplot 函式會使用這個串列
box_labels = ['normal','normal_sample','lognormal','lognormal_sample']

# 使用 boxplot 函式來建立四個盒鬚圖。 notch=False 代表這些箱子應該都是矩形，而不是在中間有缺口。 sym='.' 代表鬚之外的點是圓點，
# 而不是預設的 + 符號。 vert=True 代表盒子是垂直的，而不是水平的。 whis=1.5 指定鬚接觸的地方在第一四分位數與第三四分位數之外
# （即，Q3 + whis*IQR，IQR = 四分位範圍，Q3-Q1）。 showmeans=True 指定盒子除了顯示中位值之外，也要顯示平均值。
# labels=box_labels 代表使用 box_labels 的值來標示盒鬚圖。
ax1.boxplot(box_plot_data, notch=False, sym='.', vert=True, whis=1.5, \
				showmeans=True, labels=box_labels)
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax1.set_title('Box Plots: Resampling of Two Distributions')
ax1.set_xlabel('Distribution')
ax1.set_ylabel('Value')

plt.savefig('box_plot.png', dpi=400, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## pandas
#
# ### pandas 藉由提供可操作 Series 與 DataFrame 的 plot 函式，來簡化以 Series 與 DataFrame 內的資料繪製圖表的程序。在預設情況下，plot 函式會建立線形圖，但你可以使用 kind 引數來建立不同類型的圖。
# ### 例如，除了標準的統計圖之外，你可以用 matplotlib 來繪圖，pandas 可讓你建立其他的圖表，例如六角相形圖、散布矩陣圖、密度圖、Andrews 曲線、平行座標、滯後圖、自相關圖，與 bootstrap 圖。pandas 也可讓你輕鬆地在圖中加入輔助 y 軸、誤差線及運算列表。

# %%
#!/usr/bin/env python3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fig, axes = plt.subplots(nrows=1, ncols=3)  # fig = plt.figure(), axes = plt.subplots()，建立一個主圖表，與 3 個並列的副圖表
ax1, ax2, ax3 = axes.ravel() # 使用 ravel 函式將副圖表變成兩個變數 ax1、ax2 與 ax3

data_frame = pd.DataFrame(np.random.rand(5, 3),
						index=['Customer 1', 'Customer 2', 'Customer 3', 'Customer 4', 'Customer 5'],
						columns=pd.Index(['Metric 1', 'Metric 2', 'Metric 3'], name='Metrics'))

# 使用 pandas plot 函式，在左邊的副圖表中建立長條圖
data_frame.plot(kind='bar', ax=ax1, alpha=0.75, title='Bar Plot')

# 使用 matplotlib 函式來旋轉並指定 x 軸與 y 軸的標籤大小
plt.setp(ax1.get_xticklabels(), rotation=45, fontsize=10)
plt.setp(ax1.get_yticklabels(), rotation=0, fontsize=10)
ax1.set_xlabel('Customer')
ax1.set_ylabel('Value')
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')

# 為各個盒鬚圖元件建立一個顏色字典
colors = dict(boxes='DarkBlue', whiskers='Gray', medians='Red', caps='Black')

# 建立右邊的副圖表，盒鬚圖，使用 colors 變數來將盒鬚圖上色，並將離群點的符號改成紅點。
data_frame.plot(kind='box', color=colors, sym='r.', ax=ax3, title='Box Plot')
plt.setp(ax3.get_xticklabels(), rotation=45, fontsize=10)
plt.setp(ax3.get_yticklabels(), rotation=0, fontsize=10)
ax3.set_xlabel('Metric')
ax3.set_ylabel('Value')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')

plt.savefig('pandas_plots.png', dpi=400, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## ggplot
#
# ### ggplot 是以 R 的 ggplot2 與 Grammar of Graphics 為基礎設計的 Python 繪圖套件。 ggplot 與其他繪圖套件的主要差異在於它的語法可以明確區分資料以及實際被顯示在螢幕上的東西。為了讓你為資料建立視覺化畫面，ggplot 提供一些基本的元素；幾何圖形、美學與比例尺。它也提供其他的元素供更進階的圖表使用：統計轉換、座標系統、繪圖面與視覺主題。
#
# ### Python 的 ggplot 不像  R 的 ggplot2 套件那麼成熟，所以它沒有 ggplot2 的所有功能，也就是說，它的幾何、統計與比例尺沒有那麼多，而且也（還）沒有任何座標系統、註釋與增加功能。

# %%
#!/usr/bin/env python3
from ggplot import *  # 要先安裝套件， pip install ggplot

print(mtcars.head())
plt1 = ggplot(aes(x='mpg'), data=mtcars) +\
 		geom_histogram(fill='darkblue', binwidth=2) +\
		xlim(10, 35) + ylim(0, 10) +\
		xlab("MPG") + ylab("Frequency") +\
		ggtitle("Histogram of MPG") +\
		theme_gray() # theme_matplotlib()  # ggplot 沒有這個函數     
print(plt1)

'''
print(meat.head())
plt2 = ggplot(aes(x='date', y='beef'), data=meat) +\
		geom_line(color='purple', size=1.5, alpha=0.75) +\
		stat_smooth(colour='blue', size=2.0, span=0.15) +\
		xlab("Year") + ylab("Head of Cattle Slaughtered") +\
		ggtitle("Beef Consumption Over Time") +\
		theme_gray()  # theme_seaborn()  # ggplot 沒有這個函數    
print(plt2)
'''

print(diamonds.head())
plt3 = ggplot(diamonds, aes(x='carat', y='price', colour='cut')) +\
		geom_point(alpha=0.5) +\
		scale_color_gradient(low='#05D9F6', high='#5011D1') +\
		xlim(0, 6) + ylim(0, 20000) +\
		xlab("Carat") + ylab("Price") +\
		ggtitle("Diamond Price by Carat and Cut") +\
		theme_gray()
print(plt3)

# ggsave(plt3, "ggplot_plots.png")  # ggplot 沒有這個函數
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# <ggplot: (-9223371868995490637)>
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# <ggplot: (-9223371868995490581)>

# %% [markdown]
# ## seaborn
#
# ### seaborn 可以簡化以 Python 來建立豐富的統計圖表的程序。它是以 matplotlib 為基礎，支援 numpy 與 pandas 資料結構，並結合 scipy 與 statsmodels 統計常式。
#
# ### seaborn 提供的函式可建立標準統計圖表，包括色階分布圖、密度圖、柱形圖、盒鬚圖與散布圖。它也有函式可將成對雙變量關係、線性與非線性迴歸模型，及估計的不確定性視覺化。它可讓你檢視當你調整其他變數時，變數之間的關係，變建立格狀排列的圖表來顯示複雜的關係。它有內建的主題與調色板，可讓你製作漂亮的圖表。最後，因為它是以 matplotlib 為基礎，你可以使用 matplotlib 指令來進一步訂製你的圖表。

# %%
#!/usr/bin/env python3
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sns.set(color_codes=True)


# Simple plot of linear, quadratic, and cubic curves 簡單的線性、二次和三次曲線圖
x = np.linspace(0, 2, 100)
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend(loc="best")
plt.show()

# %%
# Histogram  長條圖，使用常態分布資料的隨機樣本
x = np.random.normal(size=1000)
sns.distplot(x, bins=20, kde=True, rug=False, label="Histogram w/o Density")
sns.utils.axlabel("Value", "Frequency")
plt.title("Histogram of a Random Sample from a Normal Distribution")
plt.legend()
plt.show()

# %%
# Scatter plot  散布圖與迴歸線，以及兩個色階分布圖
mean, cov = [5, 10], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
data_frame = pd.DataFrame(data, columns=["x", "y"])
sns.jointplot(x="x", y="y", data=data_frame, kind="reg").set_axis_labels("x", "y")
plt.suptitle("Joint Plot of Two Variables with Bivariate and Univariate Graphs")
plt.show()

# %%
# Pairwise bivariate  為 iris 資料集的所有變數建立的成對散布圖與色階分布圖
iris = sns.load_dataset("iris")
sns.pairplot(iris)
plt.show()

# %%
# Linear regression model  建立小費與帳單總額之間的散布圖與迴歸線
tips = sns.load_dataset("tips")
sns.lmplot(x="total_bill", y="tip", data=tips)
sns.lmplot(x="size", y="tip", data=tips, x_jitter=.15, ci=None)
sns.lmplot(x="size", y="tip", data=tips, x_estimator=np.mean, ci=None)
plt.show()

# %%
# Box plots  根據星期幾、一天內的時間，以及那個人有沒有抽煙，建立的帳單總額盒鬚圖
sns.boxplot(x="day", y="total_bill", hue="time", data=tips)
sns.catplot(x="time", y="total_bill", hue="smoker",
               col="day", data=tips, kind="box", height=4, aspect=.5)
plt.show()

# %%
# Bar plots
titanic = sns.load_dataset("titanic")
sns.barplot(x="sex", y="survived", hue="class", data=titanic)
sns.countplot(y="deck", hue="class", data=titanic, palette="Greens_d")
plt.show()

# %%
# Non-linear regression model
anscombe = sns.load_dataset("anscombe")
# polynomial
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'II'"),
           order=2, ci=False, scatter_kws={"s": 80})
plt.show()

# %%
# robust to outliers
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'II'"),
           robust=True, ci=False, scatter_kws={"s": 80})
plt.show()

# %%
# logistic  羅吉斯迴歸曲線，繪出大筆小費與帳單的總額關係
tips["big_tip"] = (tips.tip / tips.total_bill) > .15
sns.lmplot(x="total_bill", y="big_tip", data=tips, logistic=True, y_jitter=.03).set_axis_labels("Total Bill", "Big Tip")
plt.title("Logistic Regression of Big Tip vs. Total Bill")
plt.show()

# %%
# lowess smoother
sns.lmplot(x="total_bill", y="tip", data=tips, lowess=True)
plt.show()

# %%
# Condition on other variables
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips,
           markers=["o", "x"], palette="Set1")
sns.lmplot(x="total_bill", y="tip", hue="smoker",
           col="time", row="sex", data=tips)
plt.show()

# %%
# Control shape and size of plot
sns.lmplot(x="total_bill", y="tip", col="day", data=tips, col_wrap=2, height=3)
sns.lmplot(x="total_bill", y="tip", col="day", data=tips, aspect=.5)
plt.show()

# %%
# Plotting regression in other contexts
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg")
sns.pairplot(tips, x_vars=["total_bill", "size"], y_vars=["tip"],
             height=5, aspect=.8, kind="reg")
sns.pairplot(tips, x_vars=["total_bill", "size"], y_vars=["tip"],
             hue="smoker", height=5, aspect=.8, kind="reg")
plt.show()
