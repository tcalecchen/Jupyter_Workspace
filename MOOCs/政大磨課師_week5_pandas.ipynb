# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %ls
# Out:
#  磁碟區 C 中的磁碟是 Windows
#  磁碟區序號:  3444-EC57
#
#  C:\Users\alech\GitHub\Jupyter_Workspace\Alec-Python 的目錄
#
# 2019/04/18  下午 09:17    <DIR>          .
# 2019/04/18  下午 09:17    <DIR>          ..
# 2019/04/18  下午 08:24    <DIR>          .ipynb_checkpoints
# 2019/04/01  下午 09:40             3,278 0103 把 Python 當計算機用.ipynb
# 2019/04/01  下午 09:40            66,155 0104 Jupyter 的魔術畫圖法.ipynb
# 2019/04/01  下午 09:40             2,835 0105 勝過計算機的變數.ipynb
# 2019/04/01  下午 09:40             1,623 0106 用 Markdown 做筆記.ipynb
# 2019/04/01  下午 09:40             4,078 0107 變數好好用.ipynb
# 2019/04/01  下午 09:40            13,540 0108 串列 List 是數據分析第一步.ipynb
# 2019/04/01  下午 09:40             4,867 0109 字串 Hello World.ipynb
# 2019/04/01  下午 09:40             4,729 0110 互動的開始 input.ipynb
# 2019/04/01  下午 09:40             4,348 0201 條件判斷.ipynb
# 2019/04/01  下午 09:40             3,551 0202 用迴圈做拍拍機器人.ipynb
# 2019/04/01  下午 09:40             2,702 0203 字串完全照我們意思格式化.ipynb
# ...

# %%
df = pd.read_csv("grades.csv")

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會
# 0  劉俊安   9  10  15  10  13
# 1  胡玉華  10  10  10   8   9
# 2  黃淑婷  13  15   8  11  14
# 3  陳上紫  10  10   8   9  14
# 4  崔靜成  13  12  14  12  13
